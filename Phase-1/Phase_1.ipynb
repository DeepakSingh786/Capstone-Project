# %% [markdown]
# Phase 1 ---Data Collection/preparation part

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 1. Population of each state

# %%
df = pd.read_csv('Population.csv')
df
# Out:
#      Year                      State   Population
# 0    2001          Jammu and Kashmir      10069917
# 1    2001           Himachal Pradesh       6077248
# 2    2001                     Punjab      24289296
# 3    2001                 Chandigarh        900914
# 4    2001                Uttaranchal       8479562
# ..    ...                        ...           ...
# 415  2012                LAKSHADWEEP         64444
# 416  2012                     KERALA      33394186
# 417  2012                 TAMIL NADU      72070998
# 418  2012                 PUDUCHERRY       1245876
# 419  2012  ANDAMAN & NICOBAR ISLANDS        380397
#
# [420 rows x 3 columns]

# %% [markdown]
# #### 2. Literacy Rate of each state

# %%
df = pd.read_csv('Literacy Rate of each state.csv')
df
# Out:
#      Year India / States / Union Territories   \
# 0    2001                         A&N islands
# 1    2001                      Andhra Pradesh
# 2    2001                   Arunachal Pradesh
# 3    2001                               Assam
# 4    2001                               Bihar
# ..    ...                                 ...
# 415  2012                          Tamil Nadu
# 416  2012                             Tripura
# 417  2012                       Uttar Pradesh
# 418  2012                         Uttarakhand
# 419  2012                         West Bengal
#
#      Literacy rate as %age of population
# 0                                  81.30
# 1                                  60.47
# 2                                  54.34
# 3                                  63.25
# 4                                  47.00
# ..                                   ...
# 415                                80.33
# 416                                87.22
# ...

# %% [markdown]
# #### 3. Area of each state

# %%
df = pd.read_csv('Area of each state.csv')
df
# Out:
#          Year                    State/ Union Territory Area (sq km)
# 0   2001-2012                                Rajasthan        342239
# 1   2001-2012                           Madhya Pradesh        308252
# 2   2001-2012                               Maharashtra     3,07,713
# 3   2001-2012                            Uttar Pradesh      2,40,928
# 4   2001-2012                                    Gujrat     1,96,244
# 5   2001-2012                                 Karnataka     1,91,791
# 6   2001-2012                            Andhra Pradesh     1,62,968
# 7   2001-2012                                    Odisha     1,55,707
# 8   2001-2012                              Chhattisgarh     1,35,192
# 9   2001-2012                                Tamil Nadu     1,30,060
# 10  2001-2012                                 Telangana     1,12,077
# 11  2001-2012                                    Bihar        94,163
# 12  2001-2012                              West Bengal        88,752
# ...
